# %% [markdown]
# ### Bike Sharing Exercise
#
# **Boothcamp Tasks**
# - Create a Data Science project utilizing Time Series Forecasting and create a Github Repository for the project
# - Ideal datasets include the Bike Sharing Dataset
# - The approach is up to the learner but Forecasting is required.
# - Prepare a model for reusability
# - Explore other algorithms for machine learning in Scikit-learn
# - Select the model with the best model performance.
# - Save the model through Pickle.
# - Present the results through a Powerpoint Presentation
#
#
# **Background**
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return
# back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return
# back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of
# over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic,
# environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by
# these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration
# of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into
# a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important
# events in the city could be detected via monitoring these data.
#
# **Data Set**
#
# Bike-sharing rental process is highly correlated to the environmental and seasonal settings. For instance, weather conditions,
# precipitation, day of week, season, hour of the day, etc. can affect the rental behaviors. The core data set is related to
# the two-year historical log corresponding to years 2011 and 2012 from Capital Bikeshare system, Washington D.C., USA which is
# publicly available in http://capitalbikeshare.com/system-data. We aggregated the data on two hourly and daily basis and then
# extracted and added the corresponding weather and seasonal information. Weather information are extracted from http://www.freemeteo.com.
#
#
# - instant: record index
# - dteday : date
# - season : season (1:springer, 2:summer, 3:fall, 4:winter)
# - yr : year (0: 2011, 1:2012)
# - mnth : month ( 1 to 12)
# - holiday : weather day is holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# - weathersit :
#     - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# - atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67 (max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and register
#
# **References**
#
# Stock Market Forecasting (R- autoarima and Python)
# https://www.kdnuggets.com/2020/01/stock-market-forecasting-time-series-analysis.html

# %% [markdown]
# ### Load and Explore Sample Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") # specify to ignore warning messages
from datetime import datetime, date, time, timedelta

# %%
data = pd.read_csv("day.csv", parse_dates=['dteday'], index_col = 'dteday')
data = data.iloc[:,[2,3,14]]
data.head()
# Out:
#             yr  mnth   cnt
# dteday
# 2011-01-01   0     1   985
# 2011-01-02   0     1   801
# 2011-01-03   0     1  1349
# 2011-01-04   0     1  1562
# 2011-01-05   0     1  1600

# %%
# aggregate to weekly
logic = {'yr'  : 'first',
         'mnth': 'first',
         'cnt'   : 'sum'}

offset = timedelta(days=-6)

data = data.resample('W', loffset=offset).apply(logic)
data.head()
# Out:
#             yr  mnth   cnt
# dteday
# 2010-12-27   0     1  1786
# 2011-01-03   0     1  9408
# 2011-01-10   0     1  9025
# 2011-01-17   0     1  8770
# 2011-01-24   0     1  7699

# %%
data.to_csv("week.csv", index = True)

# %% [markdown]
# **split train test data**
# - train:Jan 2011 - Sep 2012
# - test: Oct 2012 - Dec  2012

# %%
test = data[(data['yr'] == 1) & (data['mnth'].isin([10, 11, 12]))]
#test = test.iloc[:,0:-3]
test
# Out:
#             yr  mnth    cnt
# dteday
# 2012-10-01   1    10  45948
# 2012-10-08   1    10  48161
# 2012-10-15   1    10  48717
# 2012-10-22   1    10  49331
# 2012-10-29   1    10  28762
# 2012-11-05   1    11  40675
# 2012-11-12   1    11  37299
# 2012-11-19   1    11  27315
# 2012-11-26   1    11  35137
# 2012-12-03   1    12  37762
# 2012-12-10   1    12  35966
# 2012-12-17   1    12  26696
# 2012-12-24   1    12  10720
# 2012-12-31   1    12   2729

# %%
train = data[~((data['yr'] == 1) & (data['mnth'].isin([10, 11, 12])))]
train
# Out:
#             yr  mnth    cnt
# dteday
# 2010-12-27   0     1   1786
# 2011-01-03   0     1   9408
# 2011-01-10   0     1   9025
# 2011-01-17   0     1   8770
# 2011-01-24   0     1   7699
# ...         ..   ...    ...
# 2012-08-27   1     8  48667
# 2012-09-03   1     9  47920
# 2012-09-10   1     9  55022
# 2012-09-17   1     9  50722
# 2012-09-24   1     9  52959
#
# [92 rows x 3 columns]

# %% [markdown]
# **Plot Count(Rentals) 2011 to 2012**

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax = sns.lineplot(x="dteday", y="cnt", color = "black", data=train, label = "train")
ax = sns.lineplot(x="dteday", y="cnt", color = "blue", data=test, label = "test")

#plt.tight_layout()
plt.title('Weekly Rent Count Jan 2011 to Dec 2012')
plt.show()

# %%
fig.savefig("ts_train_test.png", dpi= 600)

# %%
ts = data.copy()
ts.head()
# Out:
#             yr  mnth   cnt
# dteday
# 2010-12-27   0     1  1786
# 2011-01-03   0     1  9408
# 2011-01-10   0     1  9025
# 2011-01-17   0     1  8770
# 2011-01-24   0     1  7699

# %%
mape_all = list()
method_all = list()

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# **EWMA Models**
# - Simple Moving Average
# - Exponentially Weighted Moving Average

# %% [markdown]
# **Naive Forecast**

# %%
ts['Naive'] = ts['cnt'].shift(1)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.lineplot(x="dteday", y="cnt", color = "blue", data=ts['2012-10-01':], label = "Actual")
ax = sns.lineplot(x="dteday", y="Naive", color = "gray", data=ts['2012-10-01':], label = "Naive")

#plt.tight_layout()
plt.title('Naive Forecasting')
plt.show()

# %%
fig.savefig("pred_naive.png", dpi= 500)

# %%
# evaluate model
forecast = ts['2012-10-01':]['Naive']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("naive")
# Out:
# 48.530234937538594

# %% [markdown]
# **Simple Moving Averages**

# %%
ts['4-wk-SMA'] = ts['cnt'].rolling(window = 4).mean()
ts['8-wk-SMA'] = ts['cnt'].rolling(window = 8).mean()
ts['12-wk-SMA'] = ts['cnt'].rolling(window = 12).mean()

# %%
# plot better 
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.lineplot(x="dteday", y="cnt", color = "blue", data=ts['2012-10-01':], label = "Actual")
ax = sns.lineplot(x="dteday", y="4-wk-SMA", color = "orange", data=ts['2012-10-01':], label = "4-wk-SMA")
ax = sns.lineplot(x="dteday", y="8-wk-SMA", color = "green", data=ts['2012-10-01':], label = "8-wk-SMA")
ax = sns.lineplot(x="dteday", y="12-wk-SMA", color = "red", data=ts['2012-10-01':], label = "12-wk-SMA")

#plt.tight_layout()
plt.title('Simple Moving Averages Forecast')
plt.show()

# %%
fig.savefig("pred_sma.png", dpi= 500)

# %%
# evaluate model
forecast = ts['2012-10-01':]['4-wk-SMA']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("4-wk-SMA")
# Out:
# 64.0863500560102

# %%
# evaluate model
forecast = ts['2012-10-01':]['8-wk-SMA']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("8-wk-SMA")
# Out:
# 90.81921773905346

# %%
# evaluate model
forecast = ts['2012-10-01':]['12-wk-SMA']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("12-wk-SMA")
# Out:
# 111.74674599101458

# %% [markdown]
# **Exponentailly Weighted Moving Averages**

# %%
ts['4-wk-EWM'] = ts['cnt'].ewm(span = 4).mean()
ts['8-wk-EWM'] = ts['cnt'].ewm(span = 8).mean()
ts['12-wk-EWM'] = ts['cnt'].ewm(span = 12).mean()

# %%
# plot better 
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.lineplot(x="dteday", y="cnt", color = "blue", data=ts['2012-10-01':], label = "Actual")
ax = sns.lineplot(x="dteday", y="4-wk-EWM", color = "orange", data=ts['2012-10-01':], label = "4-wk-EWM")
ax = sns.lineplot(x="dteday", y="8-wk-EWM", color = "green", data=ts['2012-10-01':], label = "8-wk-EWM")
ax = sns.lineplot(x="dteday", y="12-wk-EWM", color = "red", data=ts['2012-10-01':], label = "12-wk-EWM")

#plt.tight_layout()
plt.title('Exponentially Weighted Moving Averages Forecast')
plt.show()

# %%
fig.savefig("pred_ewm.png", dpi= 500)

# %%
# evaluate model
forecast = ts['2012-10-01':]['4-wk-EWM']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("4-wk-EWM")
# Out:
# 49.40765984144061

# %%
# evaluate model
forecast = ts['2012-10-01':]['8-wk-EWM']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("8-wk-EWM")
# Out:
# 80.0583247120405

# %%
# evaluate model
forecast = ts['2012-10-01':]['12-wk-EWM']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("12-wk-EWM")
# Out:
# 97.99188019144471

# %% [markdown]
# **Apply ETS Decomposition on Train Data**
# - Error
# - Trend
# - Seasonality Models

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(ts['cnt'], model = "additive", freq = 52) # linear growth; freq = 365; yearly (requires 2 cycles)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 8, 7
decomposition = result
fig = decomposition.plot()
plt.show()

# %%
fig.savefig("ts_ets_decomp.png", dpi= 500)

# %% [markdown]
# **use auto arima in R to determine best parameter**
# - attach image
# - (1,0,0) & (0,1,0)[52]
#
# ![arima](arima.png "Arima")

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = sm.tsa.statespace.SARIMAX(ts['cnt'], order = (1,0,0), seasonal_order = (0,1,0, 52))

# %%
results = model.fit()

# %%
print(results.summary)
# Out:
# <bound method SARIMAXResults.summary of <statsmodels.tsa.statespace.sarimax.SARIMAXResults object at 0x000001FE14D11D68>>

# %%
ts['ARIMA'] = results.predict(start = 1, end = len(ts))

# %%
forecast = ts['2012-10-01':]['ARIMA']
actual = ts['2012-10-01':]['cnt']
mape = mean_absolute_percentage_error(actual, forecast)
print(mape)
mape_all.append(mape)
method_all.append("ARIMA")
# Out:
# 64.5679569821775

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.lineplot(x="dteday", y="cnt", color = "blue", data=ts['2012-10-01':], label = "Actual")
ax = sns.lineplot(x="dteday", y="ARIMA", color = "orange", data=ts['2012-10-01':], label = "ARIMA")

#plt.tight_layout()
plt.title('ARIMA (1,0,0) (0,1,0)[52] Forecast')
plt.show()

# %%
fig.savefig("pred_arima.png", dpi= 500)

# %% [markdown]
# ### Evaluate MAPE of Time Series

# %%
fig, ax = plt.subplots(figsize=(8,5))

ax.bar(method_all, mape_all, align='center')
ax.set_ylabel('mape')

rects = ax.patches

# Make some labels.
labels = ["label%d" % i for i in range(len(rects))]

mape_all_str = [ '%.2f' % elem for elem in mape_all ]

for rect, label in zip(rects, mape_all_str):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 1, label,
            ha='center', va='bottom')

ax.set_title('Mean Absolute Percentage Error - Forecasting Models')


plt.tight_layout()
plt.show()

# %%
fig.savefig("mape.png", dpi= 400)

# %%
mape_df = pd.DataFrame(
    {'methods': method_all,
     'mape': mape_all
    })
mape_df
# Out:
#      methods        mape
# 0      naive   48.530235
# 1   4-wk-SMA   64.086350
# 2   8-wk-SMA   90.819218
# 3  12-wk-SMA  111.746746
# 4   4-wk-EWM   49.407660
# 5   8-wk-EWM   80.058325
# 6  12-wk-EWM   97.991880
# 7      ARIMA   64.567957

# %% [markdown]
# ### Store ARIMA Model into Pickle

# %%
import pickle

# %%
# write model
pickle.dump(model, open("arima_model.pickle", "wb"))

# %%
# load model
arima_model = pickle.load(open("arima_model.pickle", "rb"))

# %%
# test model
arima_model.fit().predict(start = 100, end = 106)
# Out:
# 2012-11-26    34382.357671
# 2012-12-03    29261.706785
# 2012-12-10    39558.218854
# 2012-12-17    28883.942134
# 2012-12-24    24132.252728
# 2012-12-31    17908.153020
# 2013-01-07     2467.591534
# Freq: W-MON, Name: predicted_mean, dtype: float64
