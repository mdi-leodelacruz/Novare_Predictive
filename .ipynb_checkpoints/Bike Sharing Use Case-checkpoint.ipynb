# %% [markdown]
# ### Bike Sharing Exercise
#
# **Boothcamp Tasks**
# - Create a Data Science project utilizing Time Series Forecasting and create a Github Repository for the project
# - Ideal datasets include the Bike Sharing Dataset
# - The approach is up to the learner but Forecasting is required.
# - Prepare a model for reusability
# - Explore other algorithms for machine learning in Scikit-learn
# - Select the model with the best model performance.
# - Save the model through Pickle.
# - Present the results through a Powerpoint Presentation
#
#
# **Data Source**
#
# You are provided hourly rental data spanning two years. For this competition, the training set is comprised of the first 19 days of each month, while the test set is the 20th to the end of the month. You must predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.
#
# **Data Fields**
# - datetime - hourly date + timestamp
# - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday - whether the day is considered a holiday
# - workingday - whether the day is neither a weekend nor holiday
# - weather
#     - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp - temperature in Celsius
# - atemp - "feels like" temperature in Celsius
# - humidity - relative humidity
# - windspeed - wind speed
# - casual - number of non-registered user rentals initiated
# - registered - number of registered user rentals initiated
# - count - number of total rentals

# %% [markdown]
# ### Load and Explore Sample Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#warnings.filterwarnings('ignore')

# %%
from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

train = pd.read_csv("train.csv", parse_dates=['datetime'], date_parser=dateparse)
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test = pd.read_csv("test.csv", parse_dates=['datetime'], date_parser=dateparse)
test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
sample = pd.read_csv("sampleSubmission.csv", parse_dates=['datetime'], date_parser=dateparse)
sample.head()
# Out:
#              datetime  count
# 0 2011-01-20 00:00:00      0
# 1 2011-01-20 01:00:00      0
# 2 2011-01-20 02:00:00      0
# 3 2011-01-20 03:00:00      0
# 4 2011-01-20 04:00:00      0

# %%
train.iloc[:,1:-3].head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# **Explore Relationship between Variables and Count(Rentals)**

# %%
ax = sns.FacetGrid(train, col="season", sharey = True)
ax.map(sns.histplot, "count", edgecolor = "white", bins = 30)
ax.set_titles(col_template = "{col_name}")
ax.set_xlabels("count(rental)")
ax.set_ylabels("frequency")
plt.tight_layout()
plt.show()

# %%
ax = sns.FacetGrid(train, col="holiday", sharey = False)
ax.map(sns.histplot, "count", edgecolor = "white", bins = 30)
ax.set_titles(col_template = "{col_name}")
ax.set_xlabels("count(rental)")
ax.set_ylabels("frequency")
plt.tight_layout()
plt.show()

# %%
ax = sns.FacetGrid(train, col="workingday", sharey = False)
ax.map(sns.histplot, "count", edgecolor = "white", bins = 30)
ax.set_titles(col_template = "{col_name}")
ax.set_xlabels("count(rental)")
ax.set_ylabels("frequency")
plt.tight_layout()
plt.show()

# %%
ax = sns.FacetGrid(train, col="weather", sharey = False)
ax.map(sns.histplot, "count", edgecolor = "white", bins = 30)
ax.set_titles(col_template = "{col_name}")
ax.set_xlabels("count(rental)")
ax.set_ylabels("frequency")
plt.tight_layout()
plt.show()

# %%
ax = sns.scatterplot(
    data= train, 
    x='temp', y='count', alpha = 0.3
)
#ax.set_titles(col_template = "{col_name}")
plt.tight_layout()
plt.show()

# %%
ax = sns.scatterplot(
    data= train, 
    x='atemp', y='count', alpha = 0.3
)
#ax.set_titles(col_template = "{col_name}")
plt.tight_layout()
plt.show()

# %%
ax = sns.scatterplot(
    data= train, 
    x='humidity', y='count', alpha = 0.3
)
#ax.set_titles(col_template = "{col_name}")
plt.tight_layout()
plt.show()

# %%
ax = sns.scatterplot(
    data= train, 
    x='windspeed', y='count', alpha = 0.3
)
#ax.set_titles(col_template = "{col_name}")
plt.tight_layout()
plt.show()

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# some periods should have a count of 0 for No Bike rentals at a specified hour (1-6 am)

# %%
train.iloc[45:55,]
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 45 2011-01-02 22:00:00       1        0           0        1  9.84  10.605
# 46 2011-01-02 23:00:00       1        0           0        1  9.02  11.365
# 47 2011-01-03 00:00:00       1        0           1        1  9.02   9.850
# 48 2011-01-03 01:00:00       1        0           1        1  8.20   8.335
# 49 2011-01-03 04:00:00       1        0           1        1  6.56   6.820
# 50 2011-01-03 05:00:00       1        0           1        1  6.56   6.820
# 51 2011-01-03 06:00:00       1        0           1        1  5.74   5.305
# 52 2011-01-03 07:00:00       1        0           1        1  5.74   6.820
# 53 2011-01-03 08:00:00       1        0           1        1  5.74   6.060
# 54 2011-01-03 09:00:00       1        0           1        1  6.56   6.820
#
#     humidity  windspeed  casual  registered  count
# 45        44    19.9995       0           9      9
# ...

# %%
fig, ax = plt.subplots(figsize=(50,5))
ax = sns.lineplot(x="datetime", y="count", data=train)
plt.xticks(rotation=15)
plt.tight_layout()
plt.title('seaborn-matplotlib example')
plt.show()

# %% [markdown]
# no records in day **20 onwards** per month

# %% [markdown]
# ### Need to use a complete different bike sharing dataset to conduct time series forecasting and validation MAPE
